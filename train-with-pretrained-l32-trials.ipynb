# %%
import matplotlib.pyplot as plt
import torch
import torchvision
import seaborn as sns

from torch import nn
from torchvision import transforms
from helper_functions import set_seeds
from sklearn.metrics import f1_score

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
pretrained_vit_weights = torchvision.models.ViT_L_32_Weights.DEFAULT 

pretrained_vit = torchvision.models.vit_l_32(weights=pretrained_vit_weights).to(device)

for parameter in pretrained_vit.parameters():
    parameter.requires_grad = False
    
class_names = ['Epidural', 'Intraparenchymal', 'Intraventicular', 'Normal', 'Subarachnoid', 'Subdural']

set_seeds()
pretrained_vit.heads = nn.Linear(in_features=1024, out_features=len(class_names)).to(device)

# %%
from torchinfo import summary

summary(model=pretrained_vit, 
        input_size=(16, 3, 224, 224),
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# C:\Conda\Lib\site-packages\torch\nn\modules\activation.py:1196: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   return torch._native_multi_head_attention(
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# VisionTransformer (VisionTransformer)                        [16, 3, 224, 224]    [16, 6]              1,024                Partial
# ├─Conv2d (conv_proj)                                         [16, 3, 224, 224]    [16, 1024, 7, 7]     (3,146,752)          False
# ├─Encoder (encoder)                                          [16, 50, 1024]       [16, 50, 1024]       51,200               False
# │    └─Dropout (dropout)                                     [16, 50, 1024]       [16, 50, 1024]       --                   --
# │    └─Sequential (layers)                                   [16, 50, 1024]       [16, 50, 1024]       --                   False
# │    │    └─EncoderBlock (encoder_layer_0)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_1)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_2)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_3)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_4)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_5)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_6)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_7)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_8)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_9)                   [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_10)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_11)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_12)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_13)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_14)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_15)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_16)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_17)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_18)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_19)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_20)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_21)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_22)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    │    └─EncoderBlock (encoder_layer_23)                  [16, 50, 1024]       [16, 50, 1024]       (12,596,224)         False
# │    └─LayerNorm (ln)                                        [16, 50, 1024]       [16, 50, 1024]       (2,048)              False
# ├─Linear (heads)                                             [16, 1024]           [16, 6]              6,150                True
# ============================================================================================================================================
# Total params: 305,516,550
# Trainable params: 6,150
# Non-trainable params: 305,510,400
# Total mult-adds (Units.GIGABYTES): 5.69
# ============================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 1113.98
# Params size (MB): 818.81
# Estimated Total Size (MB): 1942.43
# ============================================================================================================================================

# %%
train_dir = './ich_dataset2-1/augmented/256/train/'
test_dir = './ich_dataset2-1/augmented/256/test/'

# %%
pretrained_vit_transforms = pretrained_vit_weights.transforms()
print(pretrained_vit_transforms)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str, 
    test_dir: str, 
    transform: transforms.Compose, 
    batch_size: int, 
    num_workers: int=NUM_WORKERS
):

  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  class_names = train_data.classes

  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
train_dataloader_pretrained, test_dataloader_pretrained, class_names = create_dataloaders(train_dir=train_dir,
                                                                                                     test_dir=test_dir,
                                                                                                     transform=pretrained_vit_transforms,
                                                                                                     batch_size=8)

# %%
from going_modular.going_modular import engine

# default optimizer
# optimizer = torch.optim.Adam(params=pretrained_vit.parameters(), 
#                              lr=1e-3)

optimizer = torch.optim.Adam(params=pretrained_vit.parameters(), 
                             lr=1e-2)

# optimizer = torch.optim.AdamW(params=pretrained_vit.parameters(), 
#                              lr=2e-5)

loss_fn = torch.nn.CrossEntropyLoss()

set_seeds()
pretrained_vit_results = engine.train(model=pretrained_vit,
                                      train_dataloader=train_dataloader_pretrained,
                                      test_dataloader=test_dataloader_pretrained,
                                      optimizer=optimizer,
                                      loss_fn=loss_fn,
                                      epochs=10,
                                      device=device)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.6684 | train_acc: 0.5005 | train_f1: 0.4999 | test_loss: 0.9015 | test_acc: 0.7097 | test_f1: 0.7076
# Epoch: 2 | train_loss: 1.1398 | train_acc: 0.6538 | train_f1: 0.6535 | test_loss: 1.1268 | test_acc: 0.6719 | test_f1: 0.6568
# Epoch: 3 | train_loss: 0.9705 | train_acc: 0.7029 | train_f1: 0.7027 | test_loss: 0.8970 | test_acc: 0.7349 | test_f1: 0.7358
# Epoch: 4 | train_loss: 0.9651 | train_acc: 0.7238 | train_f1: 0.7238 | test_loss: 0.7690 | test_acc: 0.7873 | test_f1: 0.7879
# Epoch: 5 | train_loss: 0.8520 | train_acc: 0.7545 | train_f1: 0.7545 | test_loss: 0.5927 | test_acc: 0.8185 | test_f1: 0.8155
# Epoch: 6 | train_loss: 0.8522 | train_acc: 0.7592 | train_f1: 0.7590 | test_loss: 0.6474 | test_acc: 0.8180 | test_f1: 0.8136
# Epoch: 7 | train_loss: 0.8066 | train_acc: 0.7748 | train_f1: 0.7747 | test_loss: 0.5024 | test_acc: 0.8569 | test_f1: 0.8582
# Epoch: 8 | train_loss: 0.7241 | train_acc: 0.7979 | train_f1: 0.7979 | test_loss: 0.7626 | test_acc: 0.7989 | test_f1: 0.8016
# Epoch: 9 | train_loss: 0.7468 | train_acc: 0.7977 | train_f1: 0.7976 | test_loss: 0.6860 | test_acc: 0.8095 | test_f1: 0.8110
# Epoch: 10 | train_loss: 0.7151 | train_acc: 0.8052 | train_f1: 0.8051 | test_loss: 0.7079 | test_acc: 0.8095 | test_f1: 0.8105
# [INFO] Saving model to: models\model.pth

# %%
from helper_functions import plot_loss_curves

plot_loss_curves(pretrained_vit_results)

# %%
import requests
import torch
import torchvision
from torch import nn
from going_modular.going_modular.predictions import pred_and_plot_image

custom_image_path = "normal1.jpg"
model_name = "model.pth"
device = "cuda" if torch.cuda.is_available() else "cpu"
model_file = torchvision.models.vit_l_32().to(device)
class_names = ['Epidural', 'Intraparenchymal', 'Intraventicular', 'Normal', 'Subarachnoid', 'Subdural']
model_file.heads = nn.Linear(in_features=1024, out_features=len(class_names)).to(device)
model_file.load_state_dict(torch.load(f"models/{model_name}"))

# pred_and_plot_image(model=pretrained_vit,
#                     image_path=custom_image_path,
#                     class_names=class_names)

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
import requests
import torch
import torchvision
from torch import nn
device = "cuda" if torch.cuda.is_available() else "cpu"

device
# Out:
# 'cuda'

# %%
custom_image_path = "subdural.png"

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
custom_image_path = "intraventicular.png"

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
custom_image_path = "subarachnoid.png"

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
custom_image_path = "epidural.png"

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
custom_image_path = "intraparenchymal.png"

pred_and_plot_image(model=model_file,
                    image_path=custom_image_path,
                    class_names=class_names)

# %%
# !python --version
# Out:
# Python 3.11.5

# %%
torch.__version__
# Out:
# '2.2.1'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)
